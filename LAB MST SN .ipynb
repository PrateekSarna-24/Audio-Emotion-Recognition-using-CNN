# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create an empty graph
G = nx.Graph()

# Add nodes to the graph (in this case, 5 nodes)
nodes = [1, 2, 3, 4, 5]
G.add_nodes_from(nodes)
G.add_edge(1, 2)
G.add_edge(2, 3)
G.add_edge(1, 4)
G.add_edge(5, 4)
G.add_edge(3, 4)


# Draw the graph
pos = nx.spring_layout(G)  # Layout algorithm to arrange the nodes
nx.draw(G, pos, with_labels=True, node_size=500, node_color='skyblue', font_size=10)

# Display the graph
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G= nx.connected_caveman_graph(4,4)
#G= nx.florentine_families_graph()
communities=nx.community.greedy_modularity_communities(G)
membership={}
for i, comm in enumerate(communities):
    for node in comm:
        membership[node]=i
nx.set_node_attributes(G,membership,"Community")

nx.write_gexf(G,"graph.gexf")
pos=nx.spring_layout(G)
node_colors=[membership[node] for node in G.nodes()]
plt.figure(figsize=(8,6))
nx.draw_networkx(G, pos, node_color=node_colors, cmap="tab10", with_labels=True, node_size=300)
plt.title("Community Detection with Gephi")
plt.show()

# %%
import keras

# %%
import librosa

# %%
import tensorflow
